# %% [markdown]
# # Example 10 Analysis
#
# We will plot the absorption rate as a function of mass, and compare to the sum of the results from Examples 6-9.

# %% [markdown]
# ## Packages

# %%
import numpy as np

# some personal preferences for nice plots
# %run "../../utilities/output_parser/plotter.ipynb"

# helpful functions for processing output
import sys
sys.path.append("../../utilities/output_parser")
import EXDMDataHandler
from EXDMDataHandler import EXDMData

# %% [markdown]
# ## Data

# %%
data = EXDMData(filename = './output/EXDM_out_example_10.hdf5')

# %% [markdown]
# ## Results

# %% [markdown]
# ### Absorption Rate

# %% [markdown]
# #### Data

# %%
[ masses_eV, abs_rates_1 ] = data.get_absorption_rates(g2 = 10**(-26), 
                                                    width = [0.2, 0.1, 1000])

[ masses_eV, abs_rates_2 ] = data.get_absorption_rates(g2 = 10**(-26), 
                                                    width = [1, 1, 1])

# %% [markdown]
# #### Plot

# %%
save_fig = True

fig, axes = plt.subplots(nrows=1, ncols=1, 
                             figsize=(7*1.1, 7))

log_mX_min = 0
log_mX_max = 3

log_events_min = -5
log_events_max = 1

set_custom_tick_options(axes)
set_custom_axes(axes, 'x', log_mX_min, log_mX_max,
               ax_type = 'log', 
               label = r'$m_\phi \, [\mathrm{eV}]$')
set_custom_axes(axes, 'y', log_events_min, log_events_max,
               ax_type = 'log', 
               label = r'$\# \ \mathrm{Events}$', 
               show_first = False)

axes.plot(
    np.log10(masses_eV), 
    np.log10(abs_rates_1),
)

axes.plot(
    np.log10(masses_eV), 
    np.log10(abs_rates_2),
)

fig.tight_layout()
    
if save_fig:
    plt.savefig('./output/Si_absorption_rate_total.pdf', 
                bbox_inches='tight', pad_inches = 0.075)

plt.show()

# %% [markdown]
# ### Absorption Rate (comparison with other examples)

# %% [markdown]
# #### Data

# %%
data_ex6 = EXDMData(filename = '../6/output/EXDM_out_example_6.hdf5')

[ masses_eV_ex6, abs_rates_ex6 ] = data_ex6.get_absorption_rates(g2 = 10**(-26), 
                                                                width = [0.2, 0.1, 1000])

data_ex7 = EXDMData(filename = '../7/output/EXDM_out_example_7.hdf5')

[ masses_eV_ex7, abs_rates_ex7 ] = data_ex7.get_absorption_rates(g2 = 10**(-26), 
                                                                width = [0.2, 0.1, 1000])

data_ex8 = EXDMData(filename = '../8/output/EXDM_out_example_8.hdf5')

[ masses_eV_ex8, abs_rates_ex8 ] = data_ex8.get_absorption_rates(g2 = 10**(-26), 
                                                                width = [0.2, 0.1, 1000])

data_ex9 = EXDMData(filename = '../9/output/EXDM_out_example_9.hdf5')

[ masses_eV_ex9, abs_rates_ex9 ] = data_ex9.get_absorption_rates(g2 = 10**(-26), 
                                                                width = [0.2, 0.1, 1000])

# %% [markdown]
# #### Plot

# %%
save_fig = True

fig, axes = plt.subplots(nrows=1, ncols=1, 
                             figsize=(7*1.1, 7))

log_mX_min = 0
log_mX_max = 3

log_events_min = -6
log_events_max = 1

set_custom_tick_options(axes)
set_custom_axes(axes, 'x', log_mX_min, log_mX_max,
               ax_type = 'log', 
               label = r'$m_\phi \, [\mathrm{eV}]$')
set_custom_axes(axes, 'y', log_events_min, log_events_max,
               ax_type = 'log', 
               label = r'$\# \ \mathrm{Events}$', 
               show_first = False)

axes.plot(
    np.log10(masses_eV), 
    np.log10(abs_rates_1),
    linewidth = 3
)

axes.plot(
    np.log10(masses_eV_ex6), 
    np.log10(abs_rates_ex6),
    linestyle = '--',
    label = 'vc'
)

axes.plot(
    np.log10(masses_eV_ex7), 
    np.log10(abs_rates_ex7),
    linestyle = '--',
    label = 'cc'
)

axes.plot(
    np.log10(masses_eV_ex8), 
    np.log10(abs_rates_ex8),
    linestyle = '--',
    label = 'vf'
)

axes.plot(
    np.log10(masses_eV_ex9), 
    np.log10(abs_rates_ex9),
    linestyle = '--',
    label = 'cf'
)

axes.legend(loc = 'lower left', fontsize = 20)

fig.tight_layout()
    
if save_fig:
    plt.savefig('./output/Si_absorption_rate_total_compare.pdf', 
                bbox_inches='tight', pad_inches = 0.075)

plt.show()
