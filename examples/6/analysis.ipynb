# %% [markdown]
# # Example 6 Analysis
#
# We will plot the absorption rate as a function of mass, as well as the reach on $g_{aee}$

# %% [markdown]
# ## Packages

# %%
import numpy as np

# some personal preferences for nice plots
# %run "../../utilities/output_parser/plotter.ipynb"

# helpful functions for processing output
import sys
sys.path.append("../../utilities/output_parser")
import EXDMDataHandler
from EXDMDataHandler import EXDMData

# %% [markdown]
# ## Data

# %%
data = EXDMData(filename = './output/EXDM_out_example_6.hdf5')

# %% [markdown]
# ## Results

# %% [markdown]
# ### Absorption Rate

# %% [markdown]
# #### Data

# %%
[ masses_eV, abs_rates_1 ] = data.get_absorption_rates(g2 = 10**(-26),
                                                      width = [0.2, 0.1, 1000])

[ masses_eV, abs_rates_2 ] = data.get_absorption_rates(g2 = 10**(-26),
                                                      width = [1, 1, 1])

# %% [markdown]
# #### Plot

# %%
save_fig = True

fig, axes = plt.subplots(nrows=1, ncols=1, 
                             figsize=(7*1.1, 7))

log_mX_min = 0
log_mX_max = 3

log_events_min = -5
log_events_max = 1

set_custom_tick_options(axes)
set_custom_axes(axes, 'x', log_mX_min, log_mX_max,
               ax_type = 'log', 
               label = r'$m_\phi \, [\mathrm{eV}]$')
set_custom_axes(axes, 'y', log_events_min, log_events_max,
               ax_type = 'log', 
               label = r'$\# \ \mathrm{Events}$', 
               show_first = False)

axes.plot(
    np.log10(masses_eV), 
    np.log10(abs_rates_1),
)

axes.plot(
    np.log10(masses_eV), 
    np.log10(abs_rates_2),
)

fig.tight_layout()
    
if save_fig:
    plt.savefig('./output/Si_absorption_rate_2x2x2.pdf', 
                bbox_inches='tight', pad_inches = 0.075)

plt.show()

# %% [markdown]
# ### $g_{aee}$ Constraint

# %% [markdown]
# #### Data

# %%
[ masses_eV, g_constraint_1 ] = data.get_abs_g_constraint(width = [0.2, 0.1, 1000])

[ masses_eV, g_constraint_2 ] = data.get_abs_g_constraint(width = [1, 1, 1])

# %% [markdown]
# #### Plot

# %%
save_fig = True

fig, axes = plt.subplots(nrows=1, ncols=1, 
                             figsize=(7*1.1, 7))

log_mX_min = 0
log_mX_max = 3

log_events_min = -14
log_events_max = -9

set_custom_tick_options(axes)
set_custom_axes(axes, 'x', log_mX_min, log_mX_max,
               ax_type = 'log', 
               label = r'$m_\phi \, [\mathrm{eV}]$')
set_custom_axes(axes, 'y', log_events_min, log_events_max,
               ax_type = 'log', 
               label = r'$g_{aee}$', 
               show_first = False)

axes.plot(
    np.log10(masses_eV), 
    np.log10(g_constraint_1),
)

axes.plot(
    np.log10(masses_eV), 
    np.log10(g_constraint_2),
)

fig.tight_layout()
    
if save_fig:
    plt.savefig('./output/Si_gaee_constraint_2x2x2.pdf', 
                bbox_inches='tight', pad_inches = 0.075)

plt.show()
